# %%
# !Pip install Faker
# Out:
# Collecting Faker
#   Downloading Faker-9.9.0-py3-none-any.whl (1.2 MB)
# Collecting text-unidecode==1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Installing collected packages: text-unidecode, Faker
# Successfully installed Faker-9.9.0 text-unidecode-1.3

# %%
#One can use the Faker() method to create and initialize a Faker Generator.

from faker import Faker
fake = Faker()

# %% [markdown]
# How To Create A Name, Address, And Random Text Using Faker?
#
# The name() method can be used to create a full name. If you want the only first name or last name instead of the full name, you can use the methods first_name() and last_name().
#
# Each call to these methods will generate a random name.

# %%
fake.first_name()
# Out:
# 'Cameron'

# %%
fake.last_name()
# Out:
# 'York'

# %%
fake.name()
# Out:
# 'Daniel Yates'

# %%
#For creating address and random text, you can use address() and text() methods.

fake.address()
# Out:
# '644 Green Parkways\nWalkerton, VA 39919'

# %%
fake.text()
# Out:
# 'Month laugh adult management.\nPerform couple well company.\nTen create eye evening pretty nor party. Purpose wall light shake.'

# %% [markdown]
# For creating multiple names, you can put the name() method in a for loop as follows:

# %%
for _ in range(100):
  print(fake.name())
# Out:
# Christina Hernandez
# Natasha Anderson
# Craig Scott
# Mrs. Sarah Madden
# Aaron Juarez
# Todd Horton
# Daniel Bradley
# Bryan Gonzalez
# Laura Johnson
# Denise Hess
# Dr. Teresa Lee
# Stacey Williams DVM
# Michelle Carter
# Christine Cummings
# Jessica Scott
# Dana Jones
# Johnny Walker
# Barbara Best
# Charles Floyd
# Danielle Garcia
# Scott Wilson
# Deborah Underwood
# Timothy Cisneros
# Christopher Nichols
# Kathleen Castillo
# Rachel Mccann
# Justin Murphy
# David Smith
# Andrea Miller
# Megan Raymond
# Steven Reynolds
# Justin Cox II
# Kimberly Mora
# Colleen Jacobson
# Anna Reynolds
# Arthur Flores
# James Brooks
# Christopher Munoz
# Bobby Patterson
# Steven Quinn
# Bridget Hernandez
# Jeffrey Owen
# James Rivera
# Hannah Coffey
# Stephanie Hess
# Alicia Parker
# Troy Aguilar
# Jeremy Nguyen
# Tanya Hall
# Billy Lawson
# Martha Ross
# Carol Reynolds
# Albert Stewart
# Hannah Griffin
# Patrick Peterson
# Elizabeth Roberts
# Nicole Mckinney
# Samantha Aguilar
# Jill Neal
# Robert Lambert
# John Diaz
# Andrew Green
# Seth Thomas
# John Rodriguez
# Zachary Harrison
# Michael Anderson
# Rachel Tanner
# Robin Burns
# Rebecca Kelly
# Joan Fischer
# Mrs. Kimberly Johnston
# John Saunders
# Jerry Becker
# James Beasley
# Angela Reeves
# Alyssa Castaneda
# Cory Carter
# Larry Brown
# James Pena
# Laura Lee
# James Wagner
# Christopher Oliver
# Sharon Olson
# Troy Rose
# Erica Williams
# Kenneth Clayton
# Linda Eaton
# Mr. Ryan Mcdaniel
# John Marshall
# Hannah Rios
# Miss Annette Collins
# Bernard Brown
# Terry Villarreal
# Theresa Wheeler
# Matthew Snyder
# Alice Benton
# Brendan Norton
# Isaac Peters
# Dr. Kristine Payne
# Monica Guerrero

# %% [markdown]
# How To Create The Same Dummy Data using Faker Package?
#
# In some cases, you might want to reproduce the same data set. It is possible by seeding the generator. You can use the seed() method to produce the same dummy data as follows

# %%
Faker.seed(111)
print(fake.first_name())
# Out:
# Margaret

# %% [markdown]
# How To Create Unique Dummy Data using Faker Package?
#
# To ensure that the generated dummy data is unique, you can use the .unique property of the generator.

# %%
names = [fake.unique.first_name() for i in range(100)]

# %%
names
# Out:
# ['Adrian',
#  'Gregory',
#  'Michelle',
#  'Karen',
#  'Autumn',
#  'Maurice',
#  'Jose',
#  'Keith',
#  'Cynthia',
#  'Shannon',
#  'Julie',
#  'Peggy',
#  'Alexis',
#  'Tanner',
#  'Patricia',
#  'Zachary',
#  'Laura',
#  'Richard',
#  'Emily',
#  'Samantha',
#  'Lauren',
#  'Scott',
#  'Samuel',
#  'Derrick',
#  'Joann',
#  'Jean',
#  'Kevin',
#  'Ashlee',
#  'Terrance',
#  'Russell',
#  'Crystal',
#  'Johnny',
#  'Rodney',
#  'Colleen',
#  'Charlotte',
#  'Alice',
#  'Amy',
#  'Jon',
#  'Adam',
#  'Albert',
#  'Hailey',
#  'Elizabeth',
#  'Anthony',
#  'Casey',
#  'Meghan',
#  'Tony',
#  'William',
#  'Howard',
#  'Jimmy',
#  'Austin',
#  'Jared',
#  'Joe',
#  'Jessica',
#  'Kyle',
#  'Melissa',
#  'Paula',
#  'Kaitlin',
#  'Bryan',
#  'Melinda',
#  'Renee',
#  'Bailey',
#  'Victoria',
#  'Christine',
#  'Wendy',
#  'Frederick',
#  'Chelsea',
#  'Kristin',
#  'Donna',
#  'Christy',
#  'Todd',
#  'Frank',
#  'Nicholas',
#  'Chad',
#  'Bonnie',
#  'Lisa',
#  'Kelly',
#  'Bobby',
#  'Lindsey',
#  'Candice',
#  'Nicole',
#  'Megan',
#  'Randall',
#  'Craig',
#  'Connie',
#  'Cindy',
#  'Jeremy',
#  'Mark',
#  'Alex',
#  'Julian',
#  'Brianna',
#  'Sarah',
#  'Deborah',
#  'Herbert',
#  'Damon',
#  'Jacqueline',
#  'Alicia',
#  'Melanie',
#  'Nancy',
#  'Olivia',
#  'Ryan']

# %% [markdown]
# How To Create Currency-related Dummy Data Using Faker Package?
#
# You can use the following  Faker() properties for creating cryptocurrency related dummy data
#
# cryptocurrency() – It creates cryptocurrency name and it’s corresponding code.
#
# cryptocurrency_name() – It creates cryptocurrency name.
#
# cryptocurrency_code()  – It creates cryptocurrency code.

# %%
fake.cryptocurrency_name()
# Out:
# 'TRON'

# %%
fake.cryptocurrency()
# Out:
# ('BC', 'BlackCoin')

# %% [markdown]
# You can use the following Faker() properties for creating currency related dummy data
#
# currency() – It creates currency name and it’s corresponding code.
#
# currency_name() – It creates currency name.
#
# currency_code() – It creates currency code.

# %%
fake.currency()
# Out:
# ('NZD', 'New Zealand dollar')

# %%
for _ in range(100):
  print(fake.currency())
# Out:
# ('TTD', 'Trinidad and Tobago dollar')
# ('BTN', 'Bhutanese ngultrum')
# ('KES', 'Kenyan shilling')
# ('SZL', 'Swazi lilangeni')
# ('UYU', 'Uruguayan peso')
# ('BZD', 'Belize dollar')
# ('YER', 'Yemeni rial')
# ('DOP', 'Dominican peso')
# ('BHD', 'Bahraini dinar')
# ('CVE', 'Cape Verdean escudo')
# ('KGS', 'Kyrgyzstani som')
# ('VEF', 'Venezuelan bolívar')
# ('WST', 'Samoan tālā')
# ('MNT', 'Mongolian tugrik')
# ('KZT', 'Kazakhstani tenge')
# ('CRC', 'Costa Rican colón')
# ('BHD', 'Bahraini dinar')
# ('MKD', 'Macedonian denar')
# ('SEK', 'Swedish krona')
# ('DKK', 'Danish krone')
# ('BSD', 'Bahamian dollar')
# ('CDF', 'Congolese franc')
# ('VEF', 'Venezuelan bolívar')
# ('VEF', 'Venezuelan bolívar')
# ('JPY', 'Japanese yen')
# ('BZD', 'Belize dollar')
# ('ARS', 'Argentine peso')
# ('CUP', 'Cuban peso')
# ('TVD', 'Tuvaluan dollar')
# ('AZN', 'Azerbaijani manat')
# ('PGK', 'Papua New Guinean kina')
# ('TND', 'Tunisian dinar')
# ('KPW', 'North Korean won')
# ('CNY', 'Renminbi')
# ('TZS', 'Tanzanian shilling')
# ('TRY', 'Turkish lira')
# ('UZS', 'Uzbekistani soʻm')
# ('DJF', 'Djiboutian franc')
# ('BRL', 'Brazilian real')
# ('GIP', 'Gibraltar pound')
# ('IDR', 'Indonesian rupiah')
# ('BAM', 'Bosnia and Herzegovina convertible mark')
# ('CRC', 'Costa Rican colón')
# ('THB', 'Thai baht')
# ('PYG', 'Paraguayan guarani')
# ('CDF', 'Congolese franc')
# ('SZL', 'Swazi lilangeni')
# ('KYD', 'Cayman Islands dollar')
# ('GBP', 'Pound sterling')
# ('ANG', 'Netherlands Antillean guilder')
# ('ETB', 'Ethiopian birr')
# ('PKR', 'Pakistani rupee')
# ('KGS', 'Kyrgyzstani som')
# ('LRD', 'Liberian dollar')
# ('BMD', 'Bermudian dollar')
# ('DOP', 'Dominican peso')
# ('CZK', 'Czech koruna')
# ('NZD', 'New Zealand dollar')
# ('AOA', 'Angolan kwanza')
# ('GNF', 'Guinean franc')
# ('ZWD', 'Zimbabwean dollar')
# ('EGP', 'Egyptian pound')
# ('BBD', 'Barbadian dollar')
# ('XOF', 'West African CFA franc')
# ('KPW', 'North Korean won')
# ('MGA', 'Malagasy ariar')
# ('MDL', 'Moldovan leu')
# ('RUB', 'Russian ruble')
# ('ZAR', 'South African rand')
# ('NIS', 'Israeli new shekel')
# ('TRY', 'Turkish lira')
# ('ILS', 'Israeli new shekel')
# ('ZAR', 'South African rand')
# ('MKD', 'Macedonian denar')
# ('JPY', 'Japanese yen')
# ('MNT', 'Mongolian tugrik')
# ('DKK', 'Danish krone')
# ('MZN', 'Mozambican metical')
# ('VEF', 'Venezuelan bolívar')
# ('MZN', 'Mozambican metical')
# ('KZT', 'Kazakhstani tenge')
# ('MOP', 'Macanese pataca')
# ('WST', 'Samoan tālā')
# ('UZS', 'Uzbekistani soʻm')
# ('UAH', 'Ukrainian hryvnia')
# ('CVE', 'Cape Verdean escudo')
# ('TOP', 'Tongan paʻanga')
# ('KZT', 'Kazakhstani tenge')
# ('ETB', 'Ethiopian birr')
# ('FKP', 'Falkland Islands pound')
# ('TRY', 'Turkish lira')
# ('SHP', 'Saint Helena pound')
# ('TZS', 'Tanzanian shilling')
# ('PYG', 'Paraguayan guarani')
# ('XPF', 'CFP franc')
# ('TZS', 'Tanzanian shilling')
# ('BHD', 'Bahraini dinar')
# ('LYD', 'Libyan dinar')
# ('PGK', 'Papua New Guinean kina')
# ('ZAR', 'South African rand')

# %%
fake.currency_name()
# Out:
# 'Cuban peso'

# %%
Faker.seed(0)
for _ in range(5):
    print(fake.credit_card_number())
# Out:
# 6504876475938248
# 4948924115781567
# 348778408016097
# 30535139332877
# 5358714841858395

# %%
Faker.seed(0)
for _ in range(20):
    print(fake.credit_card_provider())
# Out:
# Discover
# Discover
# Maestro
# VISA 19 digit
# JCB 15 digit
# Diners Club / Carte Blanche
# Discover
# VISA 19 digit
# Diners Club / Carte Blanche
# American Express
# JCB 16 digit
# VISA 13 digit
# JCB 15 digit
# VISA 16 digit
# VISA 19 digit
# VISA 16 digit
# Mastercard
# JCB 16 digit
# VISA 19 digit
# JCB 15 digit

# %%
Faker.seed(4)
for _ in range(1000):
    print(fake.phone_number())
# Out:
# 416.721.1068
# 038-854-2143x0443
# (445)195-6832
# 741.840.4948
# 669.467.2344
# 1074887523
# 637-425-6958
# 510.349.9315
# (470)051-4505
# 526-914-9374x2469
# (590)507-2554
# 001-173-631-0002
# +1-290-879-3501x846
# +1-373-376-7036x7363
# 300.443.8336x4250
# 919-607-6163x92547
# +1-568-345-6714x3069
# (402)797-6630
# 209.416.6380
# 295.878.7010
# 001-917-849-2051x804
# (118)763-4637x611
# 958-667-1347
# (182)522-2575x48020
# +1-418-179-7818x3645
# 200.958.7948
# 997.624.9552x619
# (924)539-5911
# (255)524-0908x1512
# (979)112-7394
# 001-693-734-5358x876
# 654.769.0428x78956
# (902)817-5941x4737
# +1-123-142-0269x988
# 083-213-0511x404
# +1-226-218-5082x862
# 478.162.2486
# +1-465-260-6040
# 212-190-3380x7827
# 001-652-893-1795x4690
# +1-349-947-5135x1095
# 751.207.8893x03159
# (418)801-3949
# 0072353546
# +1-960-267-1884x8436
# 230-764-5665x93448
# 064-942-9512
# +1-134-371-5079x321
# 811.549.9212
# 001-023-409-5595x223
# 0204713267
# +1-878-556-6002x253
# 359-395-6581x3352
# +1-300-134-5870
# 622-697-5507x2706
# 154.980.1728
# 2939590066
# 929.022.9436
# 001-585-258-9549x5808
# (593)771-1932
# (829)085-1092
# +1-249-047-4374
# 024.600.5895x13616
# 4332311004
# 886.118.5238x80012
# (218)585-4299x19919
# 2048649528
# (873)972-7980x989
# 499.975.2425
# 538-794-4525x1353
# (714)080-0082
# 356.637.6481
# 012-060-6260x83558
# (205)516-9375x968
# 001-162-176-8301x4122
# 756.564.6156x817
# +1-846-591-6939x934
# 360.640.6533
# 715-097-7173x37520
# +1-505-399-1587x400
# +1-956-945-4947x30384
# (168)585-3023
# 786-432-1091x512
# (814)904-8410
# 001-453-996-3683x0368
# (360)248-9166x892
# +1-508-699-3156x216
# 001-422-458-4280
# 001-777-359-9768x7666
# 672-373-3547
# 165-309-7783x4624
# 4001378138
# 103.203.9202
# 869-740-3714
# 375.514.5832
# 001-331-135-5048
# +1-726-077-5635
# 001-516-095-9817
# (755)369-5176x844
# (281)660-6634
# 725-771-6567
# 001-189-355-0385x4902
# 001-498-535-4348
# 817.908.1342
# (227)738-6503x59263
# 001-974-708-3241x462
# 726-673-6913x0152
# 723.621.5324x1710
# 645.491.8942
# 699-560-6421x15743
# 220.613.8462x094
# 019-797-8795x908
# 001-192-725-1199
# +1-486-217-6382x91533
# +1-281-951-5367
# 001-479-253-5924
# 596-497-6017
# (763)168-9921x1926
# +1-240-117-3904x93360
# 001-704-680-4728x075
# 881-235-2567
# 451.009.2093x39388
# (124)675-5906
# 236.307.3432
# +1-512-067-9282x7470
# 734.331.3328
# 377-238-4926
# +1-397-782-8324
# 001-015-431-0278
# 7275541104
# 827-840-7728
# 393-079-2742
# 001-202-538-8516x29955
# 001-638-953-3299x5432
# +1-011-673-2844x96297
# 4051653940
# +1-212-506-5339x18357
# (749)440-1696x6209
# (641)409-0309
# (547)211-1629x92939
# +1-506-611-9706x1045
# 773-833-1679
# +1-689-884-3103x51210
# (056)718-3744x066
# 3271677484
# 003.082.5657
# +1-052-640-0121x867
# (167)100-1379
# 068.618.2249
# (291)164-6422x5084
# (445)090-1896
# +1-830-742-1926
# 227.536.3696x4632
# 863-041-3085
# 8490340423
# 001-600-297-6699x422
# 964-346-6387x42067
# +1-526-588-7030
# +1-016-158-9367
# 001-581-521-9693
# 778.350.5166x4092
# 026-089-0393x60588
# +1-334-241-5632x02443
# 600-503-6580x2599
# (299)505-6480x577
# +1-696-781-0937

# %% [markdown]
# It also supports multiple locales. In that case, all the locales need to be provided in the python list data type.
#
# The default locale is ‘en_US’ i.e. US English.
#
# Let’s code to create 10 Hindi names.

# %%
from faker import Faker
fake = Faker('hi_IN')
for _ in range(10):
    print(fake.name())
# Out:
# शौर्य साया
# भंडारी, सुलभा
# ढींगरा, चेतना
# शान्ता लाल
# अहलुवालिया, तृष्णा
# गौतम आचार्य
# लूथरा, आनन्द
# निखिल दुआ
# तन्वी जोशी
# दूबे, यश

# %%
from faker import Faker
fake = Faker('nl_NL')
for _ in range(10):
    print(fake.name())
# Out:
# Jayden van Munster
# Rick Pison
# Maaike Köster
# Sem Kruns
# Jens Passchiers
# Jayda de Heer
# Maria van de Eerenbeemt
# Sam Lommert
# Sofie Dubois
# Sterre Geertsen

# %% [markdown]
# How To Create A Dummy Dataset Using Faker Package?
#
# We will create a dummy dataset of 100 people with attributes like job, company, residence, username, name, address, current location, mail, etc. We will use the Standard Provider ‘Profiles’ to create this data and use Pandas Dataframes to save it.

# %%
from faker import Faker
import pandas as pd
fake = Faker()
profileData = [fake.profile() for i in range(100)]
df = pd.DataFrame(profileData)
df
# Out:
#                               job                  company          ssn  \
# 0                Heritage manager           Parker-Mcclure  879-42-3913
# 1          Engineer, aeronautical            Garrett Group  180-67-6973
# 2                 Psychotherapist               Brown-Boyd  824-22-9463
# 3            Engineer, production  Bowers, Byrd and Miller  790-49-5236
# 4    Investment banker, corporate           Adams-Martinez  365-43-1960
# ..                            ...                      ...          ...
# 95  Designer, television/film set               Neal Group  711-75-6337
# 96              Ceramics designer              Jones-White  566-56-8770
# 97      Trading standards officer             Mcbride-Lowe  285-74-1170
# 98           Financial controller              Horne Group  650-23-5322
# 99            Chemist, analytical                  Fox LLC  577-67-8163
#
#                                             residence  \
# 0                 107 Jade Row\nPort Marcus, MN 97156
# 1        26488 Nelson Valleys\nRobinsonview, WY 15764
# 2             553 Whitaker Mall\nDerekshire, HI 97238
# 3   926 Griffin Gardens Suite 815\nPort Chelsea, M...
# 4    34031 Robert Oval Apt. 858\nLewismouth, ID 48768
# ..                                                ...
# 95  700 Mack Flats Suite 553\nNew Walterville, WY ...
# 96                        USNV Callahan\nFPO AA 85314
# 97                   Unit 6765 Box 8900\nDPO AP 31977
# 98              3880 Hebert Fork\nTerrytown, IN 93404
# 99           480 Thompson Isle\nNorth Alice, NM 28313
#
#               current_location blood_group  \
# 0      (-28.833334, -4.903647)         AB-
# 1     (38.692924, -170.469268)         AB-
# 2   (-52.9059875, -105.298264)          B+
# 3      (20.866152, -43.890274)          O+
# 4       (38.134587, 16.232640)          O+
# ..                         ...         ...
# 95     (-7.5283645, 49.691864)          O-
# 96    (-65.157722, 107.011083)          A-
# 97    (45.7489005, -33.718890)          B+
# 98   (89.3392295, -179.567789)          B-
# 99     (-16.143222, -8.059760)         AB-
#
#                                               website        username  \
# 0   [http://www.higgins-wood.com/, https://www.gar...  robertsontammy
# 1   [http://www.gonzalez.com/, https://bowman-cruz...         jerry59
# 2   [https://www.mayo.com/, http://anderson-yu.com...         debra23
# 3   [http://lee-smith.com/, http://soto.com/, http...         rnelson
# 4                [https://www.harrison-mitchell.com/]          jack69
# ..                                                ...             ...
# 95  [https://smith-herrera.biz/, https://koch-rive...  bartlettronald
# 96  [https://www.delacruz.biz/, http://www.farrell...     madisonhunt
# 97                          [http://www.coleman.com/]      patricia20
# 98  [http://brennan-ramirez.com/, http://www.smith...          bjones
# 99                              [https://foster.net/]       lauriecox
#
#              name sex                                            address  \
# 0   James Estrada   M    3350 Amy Extensions\nLake Shannontown, AL 27085
# 1       Adam Wall   M  19714 Delgado Mission Suite 476\nNorth Patrici...
# 2      Ryan Lopez   M   389 Edward Groves\nPort Nataliechester, TX 76849
# 3     Chad Taylor   M           37996 Walsh Isle\nHigginsshire, KS 41917
# 4    Cody Wheeler   M     405 Clayton Glens Apt. 779\nAnnabury, DC 33558
# ..            ...  ..                                                ...
# 95   Rhonda Curry   F       7788 Jennifer Common\nWilliamsberg, WA 32642
# 96   Olivia Ellis   F  29336 Marks Circle Apt. 908\nNew Brandonboroug...
# 97  Jeffrey Moore   M    263 Chapman Park Suite 284\nHayesberg, MI 15176
# 98    Tony Morgan   M  0612 Martinez Throughway Suite 937\nWest Jerem...
# 99  Diana Nichols   F   378 Armstrong Turnpike\nNew Heidimouth, CT 20195
#
#                           mail   birthdate
# 0   humphreybrandi@hotmail.com  1923-02-16
# 1           ocoleman@gmail.com  1918-09-12
# 2      michaelcooper@gmail.com  1937-10-23
# 3         eesparza@hotmail.com  1921-09-29
# 4     catherinesmith@yahoo.com  1923-02-07
# ..                         ...         ...
# 95         ubryant@hotmail.com  1989-05-29
# 96     allenhumphrey@gmail.com  2019-04-18
# 97       michael71@hotmail.com  1980-06-13
# 98            eklein@yahoo.com  1958-08-17
# 99    sandraobrien@hotmail.com  1996-10-19
#
# [100 rows x 13 columns]

# %%
# !pip install fauxfactory
# Out:
# Collecting fauxfactory
#   Downloading fauxfactory-3.1.0-py3-none-any.whl (21 kB)
# Installing collected packages: fauxfactory
# Successfully installed fauxfactory-3.1.0

# %%
# !pip install pytest-fauxfactory
# Out:
# Collecting pytest-fauxfactory
#   Downloading pytest_fauxfactory-1.1.1-py3-none-any.whl (11 kB)
# Requirement already satisfied: fauxfactory in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from pytest-fauxfactory) (3.1.0)
# Collecting pytest>=3.2
#   Downloading pytest-6.2.5-py3-none-any.whl (280 kB)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting toml
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Collecting atomicwrites>=1.0
#   Downloading atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from pytest>=3.2->pytest-fauxfactory) (0.4.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from pytest>=3.2->pytest-fauxfactory) (21.2.0)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from pytest>=3.2->pytest-fauxfactory) (21.3)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\hp\anaconda3\envs\databases\lib\site-packages (from packaging->pytest>=3.2->pytest-fauxfactory) (3.0.4)
# Installing collected packages: toml, py, pluggy, iniconfig, atomicwrites, pytest, pytest-fauxfactory
# Successfully installed atomicwrites-1.4.0 iniconfig-1.1.1 pluggy-1.0.0 py-1.11.0 pytest-6.2.5 pytest-fauxfactory-1.1.1 toml-0.10.2

# %%
string = fauxfactory.gen_string('alphanumeric', 15)

string.isalnum()
len(string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15564/171197312.py in <module>
# ----> 1 string = fauxfactory.gen_string('alphanumeric', 15)
#       2
#       3 string.isalnum()
#       4 len(string)
#
# NameError: name 'fauxfactory' is not defined

# %% [markdown]
# Using Random module from Numpy library in Python
#
# If you want only pseudo-random numbers then they can be generated using the random package. It has different functions like rand(), randint() and choice().

# %%
 print(fake.currency())

# %%
credit_card_number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15564/51224480.py in <module>
# ----> 1 credit_card_number
#
# NameError: name 'credit_card_number' is not defined
